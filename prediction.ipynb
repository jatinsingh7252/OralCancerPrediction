# %%
import pandas as pd
patient_data = {
    "Age": 45,
    "Gender": "Male",
    "Tobacco Use": "Yes",
    "Alcohol Consumption": "Yes",
    "HPV Infection": "No",
    "Betel Quid Use": "Yes"
}

print("Patient Details:")
print(patient_data)

risk_score = 0

if patient_data["Tobacco Use"] == "Yes":
    risk_score += 1

if patient_data["Alcohol Consumption"] == "Yes":
    risk_score += 1

if patient_data["HPV Infection"] == "Yes":
    risk_score += 1

if patient_data["Betel Quid Use"] == "Yes":
    risk_score += 1

if risk_score >= 3:
    diagnosis = "Positive"
    stage = "Stage 2"
    survival_rate = "70%"
else:
    diagnosis = "Negative"
    stage = "Stage 0"
    survival_rate = "95%"

    print("Prediction Results")
print("------------------")
print("Oral Cancer Diagnosis:", diagnosis)
print("Cancer Stage:", stage)
print("5-Year Survival Rate:", survival_rate)
# Out:
# Patient Details:
# {'Age': 45, 'Gender': 'Male', 'Tobacco Use': 'Yes', 'Alcohol Consumption': 'Yes', 'HPV Infection': 'No', 'Betel Quid Use': 'Yes'}
# ------------------
# Oral Cancer Diagnosis: Positive
# Cancer Stage: Stage 2
# 5-Year Survival Rate: 70%
